# %%
# %pip install -q git+https://github.com/facebookresearch/segment-anything-2.git
# %pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.5 MB/s eta 0:00:00
#   Building wheel for SAM-2 (pyproject.toml) ... done
#   Building wheel for iopath (setup.py) ... done
# python3: can't open file '/content/run_pipeline.py': [Errno 2] No such file or directory

# %%
import getpass

token = getpass.getpass("GitHub token: ")

repo_url = "https://github.com/sofaradkova/room-selector.git"
clone_url = repo_url.replace("https://", f"https://{token}@")

# !rm -rf /content/repo
# !git clone {clone_url} /content/repo

token = None
# Out:
# Cloning into '/content/repo'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 36 (delta 20), reused 35 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (36/36), 422.94 KiB | 1.83 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# %cd /content/repo
# !pwd
# !ls -la
# Out:
# /content/repo
# /content/repo
# total 40
# drwxr-xr-x 6 root root  4096 Dec  6 18:57 .
# drwxr-xr-x 1 root root  4096 Dec  6 18:57 ..
# drwxr-xr-x 2 root root  4096 Dec  6 18:57 configs
# drwxr-xr-x 4 root root  4096 Dec  6 18:57 data
# drwxr-xr-x 8 root root  4096 Dec  6 18:57 .git
# -rw-r--r-- 1 root root 12070 Dec  6 18:57 index.html
# -rw-r--r-- 1 root root  1041 Dec  6 18:57 run_pipeline.py
# drwxr-xr-x 2 root root  4096 Dec  6 18:57 src
